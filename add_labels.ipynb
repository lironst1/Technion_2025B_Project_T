# %% [markdown]
# # Add labels
#
# Display a labels layer above of an image layer using the ``add_labels`` and
# ``add_image`` APIs
#
# .. tags:: layers, visualization-basic

# %%
import numpy as np
from skimage import data
from skimage.filters import threshold_otsu
from skimage.measure import label
from skimage.morphology import closing, remove_small_objects, square
from skimage.segmentation import clear_border
import matplotlib.pyplot as plt
import napari
# %matplotlib inline

# %%
image = plt.imread(r"C:\Users\liron\OneDrive - Technion\Homework\2025B\114252 - Project T\Data\train_2\data\2025_01_29__View1__Max_C1__1_beta_cat_25x_10min_T36_C1.tif.lnk")

# %%
# # apply threshold
# thresh = threshold_otsu(image)
# bw = closing(image > thresh, square(4))
#
# # remove artifacts connected to image border
# cleared = remove_small_objects(clear_border(bw), 20)

# label image regions
label_image = plt.imread(r"C:\Users\liron\Downloads\Labels.tif")
label_image = label_image[:, :, 0].astype('uint8')

# initialize viewer with coins image
viewer = napari.view_image(image, name="image", rgb=False)

# add the labels
label_layer = viewer.add_labels(label_image, name='segmentation')

if __name__ == '__main__':
	napari.run()

# %%
plt.imshow(image);
plt.show()
plt.imshow(bw);
plt.show()
plt.imshow(cleared);
plt.show()
plt.imshow(label_image);
plt.colorbar();
plt.show()

# %%
import tifffile as tf

s = tf.imread(r"C:\Users\liron\Downloads\Labels.tif")

# %%
np.unique(s)
# Out:
# array([0, 1, 2], dtype=uint32)

# %%
plt.imshow(s);
plt.show()

# %%
plt.imsave(fname=r"C:\Users\liron\Downloads\labels0.tiff",arr=s[0], cmap='gray', format="tiff");
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 plt.imsave(fname=r"C:\Users\liron\Downloads\labels0.tiff",arr=s[0], cmap='gray', format="tiff")
#
# File ~\anaconda3\envs\myenv\lib\site-packages\matplotlib\pyplot.py:2620, in imsave(fname, arr, **kwargs)
#    2616 @_copy_docstring_and_deprecators(matplotlib.image.imsave)
#    2617 def imsave(
#    2618     fname: str | os.PathLike | BinaryIO, arr: ArrayLike, **kwargs
#    2619 ) -> None:
# -> 2620     matplotlib.image.imsave(fname, arr, **kwargs)
#
# File ~\anaconda3\envs\myenv\lib\site-packages\matplotlib\image.py:1634, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1632 pil_kwargs.setdefault("format", format)
#    1633 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1634 image.save(fname, **pil_kwargs)
#
# ...
